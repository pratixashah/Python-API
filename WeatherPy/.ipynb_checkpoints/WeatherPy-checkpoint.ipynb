# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\shahp\anaconda31\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\shahp\anaconda31\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json

url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}"

cities_final = pd.DataFrame(columns=["City","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"])

print('-'*30)
print("Beginning Data Retrieval")
print('-'*30)

i=0
j=0

for city in cities:

    response = requests.get(f"{url}&q={city}")

    if (response.status_code == 200):

        print(f"Processing Record {j} of Set {i+1} | {city}")
        j+=1

        if(j==50):
            i+=1
            j=0

        json_response = response.json()

        cities_final = cities_final.append({
                            "City":city,
                            "Lat":json_response['coord']['lat'],
                            "Lng":json_response['coord']['lon'],
                            "Max Temp":json_response['main']['temp_max'],
                            "Humidity":json_response['main']['humidity'],
                            "Cloudiness":json_response['clouds']['all'],
                            "Wind Speed":json_response['wind']['speed'],
                            "Country":json_response['sys']['country'],
                            "Date":json_response['dt']},ignore_index=True)
    else:
        print(f"City not found. Skipping...{city}")
        
print('-'*30)
print("Data Retrieval Complete")
print('-'*30)
# Out:
# ------------------------------
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 of Set 1 | dolores
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | odlabari
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | pacific grove
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | san andres
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | lavrentiya
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | kalabo
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | vao
# Processing Record 16 of Set 1 | santa isabel do rio negro
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | scarborough
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | tuy hoa
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | acapulco
# Processing Record 23 of Set 1 | ulety
# Processing Record 24 of Set 1 | prince rupert
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | bandar-e lengeh
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | obzor
# Processing Record 35 of Set 1 | mataura
# City not found. Skipping...solovetskiy
# City not found. Skipping...rungata
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | yuci
# Processing Record 39 of Set 1 | ambon
# Processing Record 40 of Set 1 | prado
# Processing Record 41 of Set 1 | khandyga
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | santa ana
# Processing Record 45 of Set 1 | puerto ayacucho
# Processing Record 46 of Set 1 | avera
# City not found. Skipping...barentsburg
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | margate
# Processing Record 46 of Set 4 | west wendover
# Processing Record 47 of Set 4 | taupo
# Processing Record 48 of Set 4 | zherdevka
# Processing Record 49 of Set 4 | naze
# Processing Record 0 of Set 5 | qarqin
# Processing Record 1 of Set 5 | makat
# Processing Record 2 of Set 5 | korla
# Processing Record 3 of Set 5 | abu zabad
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | porgera
# Processing Record 6 of Set 5 | tautira
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | leningradskiy
# City not found. Skipping...illoqqortoormiut
# Processing Record 9 of Set 5 | molchanovo
# City not found. Skipping...kadykchan
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | kaeo
# Processing Record 12 of Set 5 | san julian
# Processing Record 13 of Set 5 | marystown
# City not found. Skipping...mergui
# Processing Record 14 of Set 5 | elko
# Processing Record 15 of Set 5 | vestmannaeyjar
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | havoysund
# Processing Record 18 of Set 5 | fomboni
# Processing Record 19 of Set 5 | tuktoyaktuk
# Processing Record 20 of Set 5 | nikolayevskaya
# Processing Record 21 of Set 5 | meulaboh
# Processing Record 22 of Set 5 | shubarshi
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | suntar
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | mikhaylovka
# Processing Record 27 of Set 5 | saint-georges
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | aliwal north
# Processing Record 30 of Set 5 | ouango
# Processing Record 31 of Set 5 | namasuba
# Processing Record 32 of Set 5 | itoman
# Processing Record 33 of Set 5 | cidreira
# City not found. Skipping...asht
# Processing Record 34 of Set 5 | bontang
# Processing Record 35 of Set 5 | zhenhai
# Processing Record 36 of Set 5 | seguela
# Processing Record 37 of Set 5 | upernavik
# Processing Record 38 of Set 5 | itupiranga
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | simbahan
# Processing Record 41 of Set 5 | boddam
# Processing Record 42 of Set 5 | mont-de-marsan
# Processing Record 43 of Set 5 | tamiahua
# City not found. Skipping...grand river south east
# Processing Record 44 of Set 5 | matata
# Processing Record 45 of Set 5 | brae
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | coachella
# Processing Record 49 of Set 5 | kidal
# Processing Record 0 of Set 6 | santa cruz de la palma
# Processing Record 1 of Set 6 | balkhash
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | carbonia
# Processing Record 4 of Set 6 | jablah
# Processing Record 5 of Set 6 | riesi
# Processing Record 6 of Set 6 | oudtshoorn
# Processing Record 7 of Set 6 | sobolevo
# Processing Record 8 of Set 6 | srednekolymsk
# Processing Record 9 of Set 6 | hailey
# Processing Record 10 of Set 6 | sturgeon falls
# Processing Record 11 of Set 6 | varhaug
# City not found. Skipping...samusu
# Processing Record 12 of Set 6 | sistranda
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | sarkand
# Processing Record 15 of Set 6 | along
# City not found. Skipping...attawapiskat
# Processing Record 16 of Set 6 | lasa
# Processing Record 17 of Set 6 | moron
# Processing Record 18 of Set 6 | kysyl-syr
# Processing Record 19 of Set 6 | jumla
# City not found. Skipping...cumaribo
# Processing Record 20 of Set 6 | inirida
# City not found. Skipping...cagayan de tawi-tawi
# Processing Record 21 of Set 6 | dali
# Processing Record 22 of Set 6 | mancio lima
# Processing Record 23 of Set 6 | mareeba
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | mastic beach
# Processing Record 26 of Set 6 | ibra
# Processing Record 27 of Set 6 | lvov
# City not found. Skipping...kamenskoye
# Processing Record 28 of Set 6 | whitehorse
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | ballina
# Processing Record 31 of Set 6 | oranjemund
# Processing Record 32 of Set 6 | huanren
# Processing Record 33 of Set 6 | namtsy
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | lata
# Processing Record 36 of Set 6 | tondano
# Processing Record 37 of Set 6 | kikwit
# Processing Record 38 of Set 6 | makueni
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | bouna
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | hithadhoo
# City not found. Skipping...utiroa
# Processing Record 43 of Set 6 | poronaysk
# Processing Record 44 of Set 6 | haines junction
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | luderitz
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | alyangula
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 0 of Set 7 | lincoln
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | itarema
# Processing Record 3 of Set 7 | bacsalmas
# Processing Record 4 of Set 7 | piraquara
# Processing Record 5 of Set 7 | bilma
# Processing Record 6 of Set 7 | tura
# Processing Record 7 of Set 7 | tagbac
# Processing Record 8 of Set 7 | opuwo
# Processing Record 9 of Set 7 | himatangi
# Processing Record 10 of Set 7 | nova olimpia
# City not found. Skipping...lolua
# Processing Record 11 of Set 7 | santa teresa
# Processing Record 12 of Set 7 | sao raimundo nonato
# Processing Record 13 of Set 7 | lamu
# Processing Record 14 of Set 7 | eisenerz
# Processing Record 15 of Set 7 | port lincoln
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | sola
# Processing Record 18 of Set 7 | gayeri
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | borger
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | isheyevka
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | pevek
# Processing Record 25 of Set 7 | kamaishi
# Processing Record 26 of Set 7 | sisimiut
# Processing Record 27 of Set 7 | dourbali
# Processing Record 28 of Set 7 | ouesso
# Processing Record 29 of Set 7 | meadow lake
# Processing Record 30 of Set 7 | port shepstone
# Processing Record 31 of Set 7 | te anau
# Processing Record 32 of Set 7 | kamogawa
# Processing Record 33 of Set 7 | chapais
# Processing Record 1 of Set 9 | sandnessjoen
# Processing Record 2 of Set 9 | belle fourche
# Processing Record 3 of Set 9 | fereydun kenar
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | kearney
# Processing Record 6 of Set 9 | aklavik
# Processing Record 7 of Set 9 | south lake tahoe
# Processing Record 8 of Set 9 | la paz
# Processing Record 9 of Set 9 | panaba
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | alekseyevsk
# Processing Record 12 of Set 9 | fairbanks
# Processing Record 13 of Set 9 | high prairie
# Processing Record 14 of Set 9 | chesapeake
# Processing Record 15 of Set 9 | santa rosa
# Processing Record 16 of Set 9 | chara
# Processing Record 17 of Set 9 | scottsboro
# City not found. Skipping...palabuhanratu
# Processing Record 18 of Set 9 | lagoa
# Processing Record 19 of Set 9 | luganville
# Processing Record 20 of Set 9 | linfen
# Processing Record 21 of Set 9 | inuvik
# Processing Record 22 of Set 9 | turtas
# Processing Record 23 of Set 9 | tual
# Processing Record 24 of Set 9 | muli
# Processing Record 25 of Set 9 | goderich
# Processing Record 26 of Set 9 | pinega
# Processing Record 27 of Set 9 | progreso
# Processing Record 28 of Set 9 | zhezkazgan
# Processing Record 29 of Set 9 | obidos
# Processing Record 30 of Set 9 | pelym
# Processing Record 31 of Set 9 | pontianak
# Processing Record 32 of Set 9 | lichinga
# City not found. Skipping...tumannyy
# Processing Record 33 of Set 9 | general roca
# Processing Record 34 of Set 9 | cobija
# Processing Record 35 of Set 9 | staryy nadym
# Processing Record 36 of Set 9 | manta
# Processing Record 37 of Set 9 | anna
# Processing Record 38 of Set 9 | husavik
# Processing Record 39 of Set 9 | olafsvik
# Processing Record 40 of Set 9 | whitianga
# Processing Record 41 of Set 9 | pontefract
# Processing Record 42 of Set 9 | kutum
# Processing Record 43 of Set 9 | koroni
# Processing Record 44 of Set 9 | samarai
# Processing Record 45 of Set 9 | tahoua
# Processing Record 46 of Set 9 | yagodnoye
# Processing Record 47 of Set 9 | biak
# Processing Record 48 of Set 9 | payakumbuh
# Processing Record 49 of Set 9 | caloundra
# City not found. Skipping...mocambique
# Processing Record 0 of Set 10 | grand gaube
# Processing Record 1 of Set 10 | sao felix do xingu
# Processing Record 2 of Set 10 | zyryanskoye
# Processing Record 3 of Set 10 | sinnamary
# Processing Record 4 of Set 10 | taseyevo
# Processing Record 5 of Set 10 | ahipara
# Processing Record 6 of Set 10 | idah
# Processing Record 7 of Set 10 | matviyivka
# Processing Record 8 of Set 10 | hegang
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | komsomolskoye
# Processing Record 12 of Set 10 | tokuyama
# Processing Record 13 of Set 10 | pandan
# Processing Record 14 of Set 10 | bavly
# City not found. Skipping...gurgan
# Processing Record 15 of Set 10 | praia da vitoria
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | kargat
# Processing Record 18 of Set 10 | atar
# Processing Record 19 of Set 10 | warri
# Processing Record 20 of Set 10 | dniprorudne
# Processing Record 21 of Set 10 | cuaspud
# Processing Record 22 of Set 10 | hay river
# Processing Record 23 of Set 10 | kupang
# Processing Record 24 of Set 10 | kipushi
# Processing Record 25 of Set 10 | tuatapere
# Processing Record 26 of Set 10 | dongsheng
# Processing Record 27 of Set 10 | rocha
# Processing Record 28 of Set 10 | grafton
# Processing Record 29 of Set 10 | potosi
# City not found. Skipping...mys shmidta
# Processing Record 30 of Set 10 | suluktu
# Processing Record 31 of Set 10 | hyeres
# Processing Record 32 of Set 10 | planadas
# City not found. Skipping...candawaga
# Processing Record 33 of Set 10 | egvekinot
# Processing Record 34 of Set 10 | iskateley
# Processing Record 35 of Set 10 | sakakah
# Processing Record 36 of Set 10 | uruzgan
# Processing Record 37 of Set 10 | dubai
# Processing Record 38 of Set 10 | minden
# City not found. Skipping...cambyreta
# Processing Record 39 of Set 10 | puerto del rosario
# Processing Record 40 of Set 10 | padang
# Processing Record 41 of Set 10 | ngunguru
# Processing Record 42 of Set 10 | payo
# Processing Record 43 of Set 10 | san rafael
# Processing Record 44 of Set 10 | acarau
# Processing Record 45 of Set 10 | matara
# Processing Record 46 of Set 10 | quelimane
# Processing Record 47 of Set 10 | savannah bight
# Processing Record 48 of Set 10 | aykhal
# City not found. Skipping...maykain
# Processing Record 49 of Set 10 | bathsheba
# Processing Record 0 of Set 11 | wellington
# Processing Record 1 of Set 11 | saldanha
# Processing Record 2 of Set 11 | altamira
# Processing Record 3 of Set 11 | ostersund
# Processing Record 4 of Set 11 | esperance
# Processing Record 5 of Set 11 | faya
# City not found. Skipping...borama
# Processing Record 6 of Set 11 | kununurra
# Processing Record 7 of Set 11 | bam
# City not found. Skipping...tabiauea
# City not found. Skipping...jiddah
# Processing Record 8 of Set 11 | ostrovnoy
# Processing Record 9 of Set 11 | gravelbourg
# Processing Record 10 of Set 11 | harindanga
# Processing Record 11 of Set 11 | leshukonskoye
# Processing Record 12 of Set 11 | praxedis guerrero
# Processing Record 13 of Set 11 | mantua
# Processing Record 14 of Set 11 | beira
# Processing Record 15 of Set 11 | megion
# Processing Record 16 of Set 11 | pangai
# Processing Record 17 of Set 11 | vilvoorde
# Processing Record 18 of Set 11 | conselheiro pena
# Processing Record 19 of Set 11 | moree
# Processing Record 20 of Set 11 | purranque
# Processing Record 21 of Set 11 | akle
# Processing Record 22 of Set 11 | atherton
# Processing Record 23 of Set 11 | umm kaddadah
# City not found. Skipping...nizhneyansk
# Processing Record 24 of Set 11 | vanimo
# Processing Record 25 of Set 11 | prieska
# Processing Record 26 of Set 11 | tilichiki
# Processing Record 27 of Set 11 | gorele
# Processing Record 28 of Set 11 | kieta
# Processing Record 29 of Set 11 | ucluelet
# Processing Record 30 of Set 11 | ambatondrazaka
# Processing Record 31 of Set 11 | pimentel
# Processing Record 32 of Set 11 | piracuruca
# City not found. Skipping...nguiu
# Processing Record 33 of Set 11 | cortez
# City not found. Skipping...gardan diwal
# Processing Record 34 of Set 11 | isangel
# Processing Record 35 of Set 11 | iqaluit
# Processing Record 36 of Set 11 | dutlwe
# Processing Record 37 of Set 11 | jackson
# Processing Record 38 of Set 11 | velez-malaga
# Processing Record 39 of Set 11 | tukrah
# Processing Record 40 of Set 11 | naifaru
# City not found. Skipping...tillabery
# Processing Record 41 of Set 11 | santa clarita
# Processing Record 42 of Set 11 | great yarmouth
# Processing Record 43 of Set 11 | kamenka
# Processing Record 44 of Set 11 | otane
# Processing Record 45 of Set 11 | chegdomyn
# Processing Record 46 of Set 11 | nador
# Processing Record 47 of Set 11 | batagay-alyta
# Processing Record 48 of Set 11 | sangar
# Processing Record 49 of Set 11 | cartagena
# City not found. Skipping...artyk
# Processing Record 0 of Set 12 | takhtamygda
# Processing Record 1 of Set 12 | gallatin
# Processing Record 2 of Set 12 | yangjiang
# Processing Record 3 of Set 12 | negombo
# Processing Record 4 of Set 12 | henties bay
# Processing Record 5 of Set 12 | yamada
# City not found. Skipping...warqla
# Processing Record 6 of Set 12 | itapaci
# Processing Record 7 of Set 12 | aksarka
# Processing Record 8 of Set 12 | svetlaya
# Processing Record 9 of Set 12 | mehamn
# Processing Record 10 of Set 12 | jiayuguan
# Processing Record 11 of Set 12 | soe
# Processing Record 12 of Set 12 | kalmunai
# Processing Record 13 of Set 12 | andujar
# Processing Record 14 of Set 12 | nyagan
# Processing Record 15 of Set 12 | tartus
# Processing Record 16 of Set 12 | pala
# Processing Record 17 of Set 12 | homer
# Processing Record 18 of Set 12 | tomohon
# Processing Record 19 of Set 12 | yumen
# Processing Record 20 of Set 12 | batagay
# Processing Record 21 of Set 12 | yenagoa
# Processing Record 22 of Set 12 | lieksa
# Processing Record 23 of Set 12 | arlit
# Processing Record 24 of Set 12 | ouegoa
# Processing Record 25 of Set 12 | san roque
# Processing Record 26 of Set 12 | kinablangan
# Processing Record 27 of Set 12 | mirador
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# To export Data in to CSV file in output_data dir
cities_final.to_csv ('output_data\cities.csv', index = False, header=True)

# %%
# To Display data in DataFrame
cities_final
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            dolores -36.3132  -57.6792    290.09        67           0
# 1          cape town -33.9258   18.4232    292.04        68           0
# 2              bluff -46.6000  168.3333    284.26        76         100
# 3           odlabari  26.8333   88.6167    287.39        51           0
# 4    arraial do cabo -22.9661  -42.0278    298.34        80         100
# ..               ...      ...       ...       ...       ...         ...
# 573            arlit  18.7369    7.3853    289.02        28           0
# 574           ouegoa -20.3500  164.4333    303.17        60          51
# 575        san roque  36.2107   -5.3842    288.15        88          88
# 576      kinablangan   7.6947  126.5503    300.17        72          99
# 577          mirador  -6.3708  -44.3631    296.42        91         100
#
#      Wind Speed Country          Date
# 0          3.11      AR  1.611795e+09
# 1          7.20      ZA  1.611794e+09
# 2          8.05      NZ  1.611795e+09
# 3          2.06      IN  1.611795e+09
# 4         12.73      BR  1.611795e+09
# ..          ...     ...           ...
# 573        2.27      NE  1.611795e+09
# 574        5.07      NC  1.611795e+09
# 575        3.09      ES  1.611795e+09
# 576        2.78      PH  1.611794e+09
# 577        1.52      BR  1.611795e+09
#
# [578 rows x 9 columns]

# %%
# Summary Statistics

summary_statistics_df = cities_final

summary_statistics_df['Humidity'] = summary_statistics_df['Humidity'].astype(int)
summary_statistics_df['Cloudiness'] = summary_statistics_df['Cloudiness'].astype(int)
summary_statistics_df['Date'] = summary_statistics_df['Date'].astype(float)

summary_statistics_df.describe()

# summary_statistics_df.dtypes
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  578.000000  578.000000  578.000000  578.000000  578.000000  578.000000
# mean    20.689983   18.730552  281.327647   75.403114   56.641869    3.555104
# std     33.805501   91.550546   18.557803   18.260728   41.917945    2.650919
# min    -54.800000 -179.166700  226.550000   13.000000    0.000000    0.060000
# 25%     -6.333650  -59.988525  270.177500   67.000000    1.000000    1.460000
# 50%     25.912350   22.714400  287.330000   80.000000   75.000000    3.040000
# 75%     49.266650  100.297375  296.410000   88.000000  100.000000    5.132500
# max     78.218600  178.416700  305.210000  100.000000  100.000000   14.000000
#
#                Date
# count  5.780000e+02
# mean   1.611795e+09
# std    8.495957e+01
# min    1.611794e+09
# 25%    1.611795e+09
# 50%    1.611795e+09
# 75%    1.611795e+09
# max    1.611795e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
summary_humidity_df = cities_final.loc[cities_final['Humidity'] > 100]




summary_humidity_df['City'].count()
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.
index_list = summary_humidity_df.index
index_list
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_df = cities_final.copy()

clean_city_df = clean_city_df.drop(index_list, inplace = False)
print(f"{clean_city_df['City'].count()}")

clean_city_df['Date'] = clean_city_df['Date'].astype(int)

clean_city_df.round({'Lat': 2,'Lng':2,'Max Temp':2,'Humidity': 0, 'Cloudiness':0})
# Out:
# 578
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            dolores -36.31  -57.68    290.09        67           0
# 1          cape town -33.93   18.42    292.04        68           0
# 2              bluff -46.60  168.33    284.26        76         100
# 3           odlabari  26.83   88.62    287.39        51           0
# 4    arraial do cabo -22.97  -42.03    298.34        80         100
# ..               ...    ...     ...       ...       ...         ...
# 573            arlit  18.74    7.39    289.02        28           0
# 574           ouegoa -20.35  164.43    303.17        60          51
# 575        san roque  36.21   -5.38    288.15        88          88
# 576      kinablangan   7.69  126.55    300.17        72          99
# 577          mirador  -6.37  -44.36    296.42        91         100
#
#      Wind Speed Country        Date
# 0          3.11      AR  1611794519
# 1          7.20      ZA  1611793955
# 2          8.05      NZ  1611794519
# 3          2.06      IN  1611794520
# 4         12.73      BR  1611794520
# ..          ...     ...         ...
# 573        2.27      NE  1611794637
# 574        5.07      NC  1611794638
# 575        3.09      ES  1611794638
# 576        2.78      PH  1611794437
# 577        1.52      BR  1611794638
#
# [578 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
from datetime import date
today = date.today()

fig = plt.figure()
plt.grid()

plt.scatter(clean_city_df['Lat'],clean_city_df['Max Temp'])

plt.xlabel("Latitude")
plt.ylabel("Max Temprature(F)")
plt.title(f"City Latitude vs Max Temprature ({today.strftime('%d/%m/%Y')})")
plt.show()

fig.savefig("output_data\Lat_Temp.png")

# Analysis
# 
#

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig = plt.figure()
plt.grid()

plt.scatter(clean_city_df['Lat'],clean_city_df['Humidity'])
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title(f"City Latitude vs Humidity ({today.strftime('%d/%m/%Y')})")
plt.show()

fig.savefig("output_data\Lat_Humidity.png")

# Analysis
# 
#

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig = plt.figure()
plt.grid()

plt.scatter(clean_city_df['Lat'],clean_city_df['Cloudiness'])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs Cloudiness ({today.strftime('%d/%m/%Y')})")
plt.show()

fig.savefig("output_data\Lat_Cloundiness.png")

# Analysis
# 
#

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig = plt.figure()
plt.grid()

plt.scatter(clean_city_df['Lat'],clean_city_df['Wind Speed'])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today.strftime('%d/%m/%Y')})")
plt.show()

fig.savefig("output_data\Lat_WindSpeed.png")

# Analysis
# 
#

# %% [markdown]
# ## Linear Regression

# %%
clean_city_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            dolores -36.3132  -57.6792    290.09        67           0
# 1          cape town -33.9258   18.4232    292.04        68           0
# 2              bluff -46.6000  168.3333    284.26        76         100
# 3           odlabari  26.8333   88.6167    287.39        51           0
# 4    arraial do cabo -22.9661  -42.0278    298.34        80         100
# ..               ...      ...       ...       ...       ...         ...
# 573            arlit  18.7369    7.3853    289.02        28           0
# 574           ouegoa -20.3500  164.4333    303.17        60          51
# 575        san roque  36.2107   -5.3842    288.15        88          88
# 576      kinablangan   7.6947  126.5503    300.17        72          99
# 577          mirador  -6.3708  -44.3631    296.42        91         100
#
#      Wind Speed Country        Date
# 0          3.11      AR  1611794519
# 1          7.20      ZA  1611793955
# 2          8.05      NZ  1611794519
# 3          2.06      IN  1611794520
# 4         12.73      BR  1611794520
# ..          ...     ...         ...
# 573        2.27      NE  1611794637
# 574        5.07      NC  1611794638
# 575        3.09      ES  1611794638
# 576        2.78      PH  1611794437
# 577        1.52      BR  1611794638
#
# [578 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# %matplotlib notebook

from scipy.stats import linregress
import scipy.stats as st

# Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)
northern_hemisphere_df = clean_city_df.loc[clean_city_df['Lat']>=0]
# northern_hemisphere_df

# Southern Hemisphere (less than 0 degrees latitude)
southern_hemisphere_df = clean_city_df.loc[clean_city_df['Lat']<0]
# southern_hemisphere_df

# %%
today = date.today()

fig = plt.figure(figsize=(6,4))
# plt.grid()

plt.scatter(northern_hemisphere_df['Lat'],northern_hemisphere_df['Max Temp'])

plt.xlabel("Latitude")
plt.ylabel("Max Temprature(F)")
plt.title(f"City Latitude vs Max Temprature with Linear Regression ({today.strftime('%d/%m/%Y')})")
# plt.show()
# plt.tight_layout()
print(f"The correlation coefficient between Nothern Hemisphere City Latitude and Max Tempareture (r-Value) is {st.pearsonr(northern_hemisphere_df['Lat'],northern_hemisphere_df['Max Temp'])[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemisphere_df['Lat'],northern_hemisphere_df['Max Temp'])
regress_values = northern_hemisphere_df['Lat'] * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(northern_hemisphere_df['Lat'],regress_values,"r-")
plt.annotate(line_eq,xy=(10,240),fontsize=10,color="red")
# plt.tight_layout()
plt.show()

# fig.savefig("output_data\Lat_Temp_Line_Regression.png")

# Analysis
# 
#
# Out:
# The correlation coefficient between Nothern Hemisphere City Latitude and Max Tempareture (r-Value) is -0.8367228143030903

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemisphere_df

plt.figure(figsize=(6,4))
plt.scatter(southern_hemisphere_df['Lat'], southern_hemisphere_df['Max Temp'])

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title(f"Latitude vs Max Temp with Regression Line ({ time.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Southern Hemisphere City Latitude and Max Tempareture (r-Value) is {st.pearsonr(southern_hemisphere_df['Lat'],southern_hemisphere_df['Max Temp'])[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemisphere_df['Lat'], southern_hemisphere_df['Max Temp'])
regress_values = southern_hemisphere_df['Lat'] * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_hemisphere_df['Lat'],regress_values,"r-")
plt.annotate(line_eq,xy=(-30,280),fontsize=10,color="red")
plt.show()

# Analysis
# 
#
# Out:
# The correlation coefficient between Southern Hemisphere City Latitude and Max Tempareture (r-Value) is 0.5004735544422964

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(6,4))

plt.scatter(northern_hemisphere_df['Lat'],northern_hemisphere_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Northern Hemisphere City Latitude vs Humidity with Linear Regression ({time.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Northern Hemisphere City Latitude and Humidity (r-Value) is {st.pearsonr(northern_hemisphere_df['Lat'],northern_hemisphere_df['Humidity'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(northern_hemisphere_df['Lat'],northern_hemisphere_df['Humidity'])
regress_value = northern_hemisphere_df['Lat'] * slope + intercept

line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(northern_hemisphere_df['Lat'],regress_value,'r-')
plt.annotate(line_eq,xy=(50,20),fontsize=10,color="red")
plt.show()

# Analysis
# 
#
# Out:
# The correlation coefficient between Northern Hemisphere City Latitude and Humidity (r-Value) is 0.2841687187108962

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(6,4))
plt.scatter(southern_hemisphere_df['Lat'],southern_hemisphere_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Southern Hemisphere City Latitude vs Humidity with Linear Regression ({time.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Southern Hemisphere City Latitude and Humidity (r-Value) is {st.pearsonr(southern_hemisphere_df['Lat'],southern_hemisphere_df['Humidity'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(southern_hemisphere_df['Lat'],southern_hemisphere_df['Humidity'])
regress_value = southern_hemisphere_df['Lat'] * slope + intercept

line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"

plt.plot(southern_hemisphere_df['Lat'], regress_value,'r-')
plt.annotate(line_eq,xy=(-20,30),fontsize=10,color="red")
plt.show()

# Analysis
# 
#
# Out:
# The correlation coefficient between Southern Hemisphere City Latitude and Humidity (r-Value) is 0.35071358467241737

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig = plt.figure(figsize=(6,4))

plt.scatter(northern_hemisphere_df['Lat'],northern_hemisphere_df['Cloudiness'])

plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"Northern Hemisphere City Latitude vs Cloudiness ({today.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Northern Hemisphere City Latitude and Humidity (r-Value) is {st.pearsonr(northern_hemisphere_df['Lat'],northern_hemisphere_df['Cloudiness'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(northern_hemisphere_df['Lat'],northern_hemisphere_df['Cloudiness'])
regress_value = northern_hemisphere_df['Lat'] * slope + intercept

line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"

plt.plot(northern_hemisphere_df['Lat'], regress_value,'r-')
plt.annotate(line_eq,xy=(50,30),fontsize=10,color="red")
plt.show()

# Analysis
# 
#
# Out:
# The correlation coefficient between Northern Hemisphere City Latitude and Humidity (r-Value) is 0.23951265736931895

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig = plt.figure(figsize=(6,4))

plt.scatter(southern_hemisphere_df['Lat'],southern_hemisphere_df['Cloudiness'])

plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"Southern Hemisphere City Latitude vs Cloudiness ({today.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Southern Hemisphere City Latitude and Humidity (r-Value) is {st.pearsonr(southern_hemisphere_df['Lat'],southern_hemisphere_df['Cloudiness'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(southern_hemisphere_df['Lat'],southern_hemisphere_df['Cloudiness'])
regress_value = southern_hemisphere_df['Lat'] * slope + intercept

line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"

plt.plot(southern_hemisphere_df['Lat'], regress_value,'r-')
plt.annotate(line_eq,xy=(-50,20),fontsize=10,color="red")
plt.show()

# Analysis
# 
#
# Out:
# The correlation coefficient between Southern Hemisphere City Latitude and Humidity (r-Value) is 0.27771341932602694

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig = plt.figure(figsize=(6,4))

plt.scatter(northern_hemisphere_df['Lat'],northern_hemisphere_df['Wind Speed'])

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"Northern Hemisphere City Latitude vs Wind Speed ({today.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Northern Hemisphere City Latitude and Wind Speed (r-Value) is {st.pearsonr(northern_hemisphere_df['Lat'],northern_hemisphere_df['Wind Speed'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(northern_hemisphere_df['Lat'],northern_hemisphere_df['Wind Speed'])
regress_value = northern_hemisphere_df['Lat'] * slope + intercept

line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"

plt.plot(northern_hemisphere_df['Lat'], regress_value,'r-')
plt.annotate(line_eq,xy=(50,12),fontsize=10,color="red")
plt.show()


# Analysis
# 
#
# Out:
# The correlation coefficient between Northern Hemisphere City Latitude and Wind Speed (r-Value) is 0.05385660441196719

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig = plt.figure(figsize=(6,4))

plt.scatter(southern_hemisphere_df['Lat'],southern_hemisphere_df['Wind Speed'])

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"Southern Hemisphere City Latitude vs Wind Speed ({today.strftime('%d/%m/%Y')})")

print(f"The correlation coefficient between Southern Hemisphere City Latitude and Wind Speed (r-Value) is {st.pearsonr(southern_hemisphere_df['Lat'],southern_hemisphere_df['Wind Speed'])[0]}")
(slope, intercept, r_value, p_value, stderr) = linregress(southern_hemisphere_df['Lat'],southern_hemisphere_df['Wind Speed'])
regress_value = southern_hemisphere_df['Lat'] * slope + intercept

line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"

plt.plot(southern_hemisphere_df['Lat'], regress_value,'r-')
plt.annotate(line_eq,xy=(-50,12),fontsize=10,color="red")
plt.show()


# Analysis
# 
#
# Out:
# The correlation coefficient between Southern Hemisphere City Latitude and Wind Speed (r-Value) is -0.32644112235506384
